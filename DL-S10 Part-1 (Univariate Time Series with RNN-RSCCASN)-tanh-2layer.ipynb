# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# <h1 style="text-align: center;">Deep Learning<br><br>Session - 10 Part -1<br><br>Univariate Time Series Forecasting with RNN<br><br>RSCCASN<br><h1>

# %% [markdown]
# # RNN (Time Series)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10,6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Data
#
# Release: Advance Monthly Sales for Retail and Food Services
# Units:  Millions of Dollars, Not Seasonally Adjusted
#
# Frequency:  Monthly
#
# The value for the most recent month is an advance estimate that is based on data from a subsample of firms from the larger Monthly Retail Trade Survey. The advance estimate will be superseded in following months by revised estimates derived from the larger Monthly Retail Trade Survey. The associated series from the Monthly Retail Trade Survey is available at https://fred.stlouisfed.org/series/MRTSSM448USN
#
# Information about the Advance Monthly Retail Sales Survey can be found on the Census website at https://www.census.gov/retail/marts/about_the_surveys.html
#
# Suggested Citation:
# U.S. Census Bureau, Advance Retail Sales: Clothing and Clothing Accessory Stores [RSCCASN], retrieved from FRED, Federal Reserve Bank of St. Louis; https://fred.stlouisfed.org/series/RSCCASN, November 16, 2019.
#
# https://fred.stlouisfed.org/series/RSCCASN

# %%
df = pd.read_csv('RSCCASN.csv',
                 index_col='DATE',
                 parse_dates=True
                )

# %%
df.head()
# Out:
#             RSCCASN
# DATE
# 1992-01-01     6938
# 1992-02-01     7524
# 1992-03-01     8475
# 1992-04-01     9401
# 1992-05-01     9558

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 334 entries, 1992-01-01 to 2019-10-01
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   RSCCASN  334 non-null    int64
# dtypes: int64(1)
# memory usage: 5.2 KB

# %%
df.columns = ['Sales']

# %%
df.plot(figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# ## Preprocessing of Data

# %% [markdown]
# ### Train Test Split

# %%
len(df)
# Out:
# 334

# %%
test_size = 24

# %%
test_ind = len(df)- test_size
test_ind
# Out:
# 310

# %%
train = df.iloc[:test_ind]
test = df.iloc[test_ind:]

# %%
train
# Out:
#             Sales
# DATE
# 1992-01-01   6938
# 1992-02-01   7524
# 1992-03-01   8475
# 1992-04-01   9401
# 1992-05-01   9558
# ...           ...
# 2017-06-01  20322
# 2017-07-01  20535
# 2017-08-01  22536
# 2017-09-01  19720
# 2017-10-01  20307
#
# [310 rows x 1 columns]

# %%
test
# Out:
#             Sales
# DATE
# 2017-11-01  24438
# 2017-12-01  33720
# 2018-01-01  15881
# 2018-02-01  18585
# 2018-03-01  22404
# 2018-04-01  20616
# 2018-05-01  23764
# 2018-06-01  21589
# 2018-07-01  21919
# 2018-08-01  23381
# 2018-09-01  20260
# 2018-10-01  21473
# 2018-11-01  25831
# 2018-12-01  34706
# 2019-01-01  16410
# 2019-02-01  18134
# 2019-03-01  22093
# 2019-04-01  21597
# 2019-05-01  23200
# 2019-06-01  21123
# 2019-07-01  21714
# 2019-08-01  23791
# 2019-09-01  19695
# 2019-10-01  21113

# %% [markdown]
# ### Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
train_scaled = scaler.fit_transform(train)
test_scaled = scaler.transform(test)

# %% [markdown]
# ## Time Series Generator

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
# help(TimeseriesGenerator)

# %%
length = 12
batch_size = 1
generator = TimeseriesGenerator(train_scaled, train_scaled, length = length, batch_size = batch_size)

# %%
len(generator)
# Out:
# 298

# %%
generator[0]
# Out:
# (array([[[0.        ],
#          [0.02127505],
#          [0.05580163],
#          [0.08942056],
#          [0.09512053],
#          [0.08146965],
#          [0.07860151],
#          [0.12979233],
#          [0.09566512],
#          [0.1203892 ],
#          [0.15426227],
#          [0.41595266]]]),
#  array([[0.02047633]]))

# %%
X, y = generator[0]

# %%
print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')
# Out:
# Given the Array:
# [0.         0.02127505 0.05580163 0.08942056 0.09512053 0.08146965
#  0.07860151 0.12979233 0.09566512 0.1203892  0.15426227 0.41595266]
# Predict this y:
#  [[0.02047633]]

# %% [markdown]
# ## Modelling

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

# %%
n_features = train_scaled.shape[1]

# %%
model = Sequential()
model.add(LSTM(100, activation = 'tanh', return_sequences=True, input_shape = (length, n_features)))
model.add(LSTM(50, activation = 'tanh'))
model.add(Dense(1))
model.compile(optimizer = 'adam', loss = 'mse')

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_14 (LSTM)              (None, 12, 100)           40800
#
#  lstm_15 (LSTM)              (None, 50)                30200
#
#  dense_4 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 71,051
# Trainable params: 71,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
# params = 4 * ((size_of_input + 1) * size_of_output + size_of_output^2)
4 * ((1+1)*100+(100**2))
# Out:
# 40800

# %%
4 * ((100+1)*50+(50**2))
# Out:
# 30200

# %% [markdown]
# ### EarlyStopping and Validation Generator

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor = 'val_loss', patience = 5)

# %%
validation_generator = TimeseriesGenerator(test_scaled, test_scaled, length = length, batch_size = batch_size)

# %%
len(validation_generator)
# Out:
# 12

# %%
model.fit_generator(generator,
                    epochs = 20,
                    validation_data = validation_generator,
                    callbacks = [early_stop])
# Out:
# Epoch 1/20
# 298/298 [==============================] - 5s 9ms/step - loss: 0.0212 - val_loss: 0.0250
# Epoch 2/20
# 298/298 [==============================] - 2s 7ms/step - loss: 0.0199 - val_loss: 0.0289
# Epoch 3/20
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0180 - val_loss: 0.0232
# Epoch 4/20
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0171 - val_loss: 0.0264
# Epoch 5/20
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0175 - val_loss: 0.0245
# Epoch 6/20
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0147 - val_loss: 0.0235
# Epoch 7/20
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0151 - val_loss: 0.0219
# Epoch 8/20
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0153 - val_loss: 0.0217
# Epoch 9/20
# 298/298 [==============================] - 2s 7ms/step - loss: 0.0126 - val_loss: 0.0351
# Epoch 10/20
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0098 - val_loss: 0.0154
# Epoch 11/20
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0103 - val_loss: 0.0285
# Epoch 12/20
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0086 - val_loss: 0.0119
# Epoch 13/20
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0088 - val_loss: 0.0114
# Epoch 14/20
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0076 - val_loss: 0.0071
# Epoch 15/20
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0054 - val_loss: 0.0070
# Epoch 16/20
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0055 - val_loss: 0.0091
# Epoch 17/20
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0041 - val_loss: 0.0047
# Epoch 18/20
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0033 - val_loss: 0.0095
# Epoch 19/20
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0032 - val_loss: 0.0081
# Epoch 20/20
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0023 - val_loss: 0.0033

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Evaluate on Test Data

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
def eval_metrics(actual, pred):
    rmse = np.sqrt(mean_squared_error(actual, pred))
    mae = mean_absolute_error(actual, pred)
    mse = mean_squared_error(actual, pred)
    score = r2_score(actual, pred)
    return print("r2_score:", score, "\nmae:", mae, "\nmse:",mse, "\nrmse:",rmse)

# %%
predictions_scaled = []

first_eval_batch = train_scaled[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(length):
    
    # get prediction 1 time stamp ahead
    current_pred = model.predict(current_batch)
    
    # store prediction
    predictions_scaled.append(current_pred[0]) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:, 1:, :], [current_pred], axis=1)

# %%
predictions_scaled
# Out:
# [array([0.7004472], dtype=float32),
#  array([0.9414229], dtype=float32),
#  array([0.3921764], dtype=float32),
#  array([0.4737143], dtype=float32),
#  array([0.56851745], dtype=float32),
#  array([0.5687992], dtype=float32),
#  array([0.57428616], dtype=float32),
#  array([0.5292444], dtype=float32),
#  array([0.5295515], dtype=float32),
#  array([0.5387687], dtype=float32),
#  array([0.4897409], dtype=float32),
#  array([0.55636567], dtype=float32)]

# %%
eval_metrics(test_scaled[:length], predictions_scaled)
# Out:
# r2_score: 0.9119607047142944
# mae: 0.03667891863003186
# mse: 0.0019498437284678155
# rmse: 0.04415703486951785

# %% [markdown]
# ### Inverse Transformations and Comparing

# %%
predictions = scaler.inverse_transform(predictions_scaled)

# %%
compare = test[:12]

# %%
compare['Predictions'] = predictions

# %%
compare
# Out:
#             Sales  Predictions
# DATE
# 2017-11-01  24438    26231.118
# 2017-12-01  33720    32868.552
# 2018-01-01  15881    17740.106
# 2018-02-01  18585    19985.986
# 2018-03-01  22404    22597.245
# 2018-04-01  20616    22605.005
# 2018-05-01  23764    22756.138
# 2018-06-01  21589    21515.508
# 2018-07-01  21919    21523.967
# 2018-08-01  23381    21777.845
# 2018-09-01  20260    20427.424
# 2018-10-01  21473    22262.536

# %%
compare.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
eval_metrics(compare.Sales, compare.Predictions)
# Out:
# r2_score: 0.9119607047142945
# mae: 1010.2841347455969
# mse: 1479291.716374134
# rmse: 1216.2613684459989

# %% [markdown]
# ## Retrain and Forecasting

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(df)

# %%
generator = TimeseriesGenerator(scaled_full_data, scaled_full_data, length = length, batch_size = batch_size)

# %%
len(df)
# Out:
# 334

# %%
len(generator)
# Out:
# 322

# %%
model = Sequential()
model.add(LSTM(100, activation = 'tanh', return_sequences=True, input_shape = (length, n_features)))
model.add(LSTM(50, activation = 'tanh'))
model.add(Dense(1))
model.compile(optimizer = 'adam', loss = 'mse')

model.fit_generator(generator, epochs=15)
# Out:
# Epoch 1/15
# 322/322 [==============================] - 4s 6ms/step - loss: 0.0226
# Epoch 2/15
# 322/322 [==============================] - 2s 6ms/step - loss: 0.0195
# Epoch 3/15
# 322/322 [==============================] - 2s 6ms/step - loss: 0.0189
# Epoch 4/15
# 322/322 [==============================] - 2s 6ms/step - loss: 0.0167
# Epoch 5/15
# 322/322 [==============================] - 2s 7ms/step - loss: 0.0169
# Epoch 6/15
# 322/322 [==============================] - 2s 7ms/step - loss: 0.0170
# Epoch 7/15
# 322/322 [==============================] - 2s 7ms/step - loss: 0.0179
# Epoch 8/15
# 322/322 [==============================] - 2s 6ms/step - loss: 0.0140
# Epoch 9/15
# 322/322 [==============================] - 2s 6ms/step - loss: 0.0138
# Epoch 10/15
# 322/322 [==============================] - 2s 6ms/step - loss: 0.0140
# Epoch 11/15
# 322/322 [==============================] - 2s 6ms/step - loss: 0.0121
# Epoch 12/15
# 322/322 [==============================] - 2s 7ms/step - loss: 0.0108
# Epoch 13/15
# 322/322 [==============================] - 2s 6ms/step - loss: 0.0085
# Epoch 14/15
# 322/322 [==============================] - 2s 6ms/step - loss: 0.0076
# Epoch 15/15
# 322/322 [==============================] - 2s 6ms/step - loss: 0.0068

# %%
scaled_full_data.shape
# Out:
# (334, 1)

# %%
scaled_full_data[-length:].shape
# Out:
# (12, 1)

# %%
forecast = []
# Replace periods with whatever forecast length you want

first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(length):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)
    
    # store prediction
    forecast.append(current_pred[0]) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:, 1:, :], [current_pred], axis = 1)

# %%
forecast = scaler.inverse_transform(forecast)

# %%
forecast
# Out:
# array([[27195.14038754],
#        [30421.62963676],
#        [17872.00223708],
#        [19832.90555453],
#        [22295.2757659 ],
#        [22068.26273823],
#        [22512.90454865],
#        [21152.02486038],
#        [21629.88913059],
#        [22130.04508686],
#        [20423.93157101],
#        [23148.28819656]])

# %%
df
# Out:
#             Sales
# DATE
# 1992-01-01   6938
# 1992-02-01   7524
# 1992-03-01   8475
# 1992-04-01   9401
# 1992-05-01   9558
# ...           ...
# 2019-06-01  21123
# 2019-07-01  21714
# 2019-08-01  23791
# 2019-09-01  19695
# 2019-10-01  21113
#
# [334 rows x 1 columns]

# %%
forecast_index = pd.date_range(start = '2019-11-01', periods = length, freq = 'MS')

# %% [markdown]
# https://stackoverflow.com/questions/35339139/what-values-are-valid-in-pandas-freq-tags

# %%
forecast_index
# Out:
# DatetimeIndex(['2019-11-01', '2019-12-01', '2020-01-01', '2020-02-01',
#                '2020-03-01', '2020-04-01', '2020-05-01', '2020-06-01',
#                '2020-07-01', '2020-08-01', '2020-09-01', '2020-10-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
forecast_df = pd.DataFrame(data = forecast, index = forecast_index, columns = ['Forecast'])

# %%
forecast_df
# Out:
#             Forecast
# 2019-11-01 27195.140
# 2019-12-01 30421.630
# 2020-01-01 17872.002
# 2020-02-01 19832.906
# 2020-03-01 22295.276
# 2020-04-01 22068.263
# 2020-05-01 22512.905
# 2020-06-01 21152.025
# 2020-07-01 21629.889
# 2020-08-01 22130.045
# 2020-09-01 20423.932
# 2020-10-01 23148.288

# %%
plt.figure(figsize = (16, 8))
plt.plot(df.index, df['Sales'])
plt.plot(forecast_df.index, forecast_df['Forecast'])

# %% [markdown]
# ### Joining pandas plots
#
# https://stackoverflow.com/questions/13872533/plot-different-dataframes-in-the-same-figure

# %%
ax = df.plot()
forecast_df.plot(ax = ax, figsize = (16, 8));

# %%
ax = df.plot()
forecast_df.plot(ax = ax, figsize = (16, 8))
plt.xlim('2018-01-01', '2020-12-01')
# Out:
# (576.0, 611.0)

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
